# %% [markdown]
# # 1B Isolation Forest Baseline
#
# This notebook is reserved for persistent training and evaluation exploration tied to the baseline `Isolation Forest` implementation.
#
# Use it to document:
# - training dataset checks
# - feature distribution inspection
# - score distribution analysis
# - threshold calibration notes

# %%
from pathlib import Path
import json

repo_root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
training_config_path = repo_root / 'configs' / 'training' / 'iforest_baseline_v1.json'
evaluation_config_path = repo_root / 'configs' / 'evaluation' / 'threshold_calibration_v1.json'

training_config = json.loads(training_config_path.read_text(encoding='utf-8'))
evaluation_config = json.loads(evaluation_config_path.read_text(encoding='utf-8'))

print(training_config['model_version'])
print(training_config['hyperparameters'])
print(evaluation_config['recommended_threshold_policy'])
