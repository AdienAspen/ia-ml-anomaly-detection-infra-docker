# %% [markdown]
# # 1B Dataset Foundations
#
# This notebook is the persistent engineering entrypoint for dataset design in block `1B`.
#
# Goals:
# - confirm alignment with `1A` contracts and reference datasets
# - inspect profile configs and output targets
# - keep reproducible notes next to the codebase

# %%
from pathlib import Path
import json

repo_root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
profile_path = repo_root / 'configs' / 'dataset_profiles' / 'training_normal_v1.json'
feature_contract_path = repo_root / 'contracts' / 'feature_contract_v1.json'

print('repo_root =', repo_root)
print('profile_path =', profile_path)
print('feature_contract_path =', feature_contract_path)
print(json.loads(profile_path.read_text(encoding='utf-8'))['row_count_target'])
print(json.loads(feature_contract_path.read_text(encoding='utf-8'))['frozen_feature_columns'])
